# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aerofit = pd.read_csv("aerofit_treadmill.csv")
aerofit
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
aerofit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
aerofit.shape #180 rows and 9 columns
# Out:
# (180, 9)

# %%
aerofit.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
aerofit.groupby("Product")["Income"].mean()
# Out:
# Product
# KP281    46418.025
# KP481    48973.650
# KP781    75441.575
# Name: Income, dtype: float64

# %%
aerofit.groupby("Product")["Fitness"].mean()
# Out:
# Product
# KP281    2.9625
# KP481    2.9000
# KP781    4.6250
# Name: Fitness, dtype: float64

# %%
aerofit.groupby("Product")["Usage"].mean()
# Out:
# Product
# KP281    3.087500
# KP481    3.066667
# KP781    4.775000
# Name: Usage, dtype: float64

# %%
sns.countplot(x = "Product" , data = aerofit, palette = "rainbow_r")
plt.show()
# Out:
# <ipython-input-27-8eb9c9c2c94b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Product" , data = aerofit, palette = "rainbow_r")

# %% [markdown]
# #Observations
#
#
# 1.   KP281 is the most purchased product having the count of 80.
# 2.   KP481 is the second most purchased product having the count of 60.
# 3.   Lastly KP781 is the purchased product having the count of 40.

# %%
sns.countplot(x = "Gender", data = aerofit, hue = "Gender")
plt.show()

# %% [markdown]
# *  Male bought most treadmills with a count of more than 100
# *  Female is the second most frequent buyer with count of roughly 75.

# %%
sns.countplot(x = "Product", hue = "Gender",palette = "YlGnBu", data = aerofit)
plt.show()

# %% [markdown]
# Furthermore...
#
# *   for the KP281, Gender is not making any difference as both purchases by male & female are Equal.
# *   The purchase of KP781 from male customers is very high as compared to the purchase from female customers of that same product.

# %%
sns.countplot(x="Usage",  data=aerofit , hue="Gender")
plt.show()

# %% [markdown]
# 1.   Majority of males seems to use treadmill 4 times per week.
# 2.   Followed by males using 3 times per week. Most of the women seems to use treadmills 3 times per week.
# 3.   Very few males use treadmills 7 times per week, while no female seems to using 7 times per week.

# %%
sns.countplot(x = "Fitness" , data = aerofit , hue = "Gender")
plt.show()

# %% [markdown]
# 1.   Both Genders are Moderately fit(Fitness rating = 3)
# 2.   More Men have a rating of 5 than Women
# 3.   There are more women who have a rating of 2 than men.

# %%
sns.kdeplot(x = "Miles", data = aerofit, hue = "Gender")
plt.show()

# %% [markdown]
# 1.   Both Genders roughly peak at 80-100 miles.
# 2.   Gap in distribution starts to occurs onwards of 150 miles & Closes around 220 miles
# 3.   very few men walk on treadmill for more than 350 miles while very few women walk beyond 300 miles.

# %%
sns.boxplot(x = "Age" , data = aerofit)
plt.show()

# %%
p75, p25 = np.percentile(aerofit['Age'], [75 ,25])
iqr_age = p75 - p25
print(p25)
print(p75)
iqr_age
# Out:
# 24.0
# 33.0
# 9.0

# %% [markdown]
# *   Most common age range is between 24-33 years
# *   There are few data points above 46(i.e. Outliers)
# *   Difference between 25th & 75th percentile is 9 years.

# %%
sns.boxplot(x = "Age" , y = "Product", data = aerofit, hue = "Product")
plt.show()

# %% [markdown]
# 1.   Age distribution in KP281 is maximum, followed by KP481, and KP781 respectively.
# 2.   Age of KP281 customers is roughly in the range of 22-33 years.
# 3.   Age of KP481 customers is roughly in the range of 23-34 years.
# 4.   Age of KP781 customers is roughly in the range of 24-31 years.
# 5.   Median ages of KP281,KP481 and KP781 are 26,26 and 27 respectively.

# %%
sns.countplot(x="MaritalStatus", data = aerofit, palette="BuGn")
plt.show()
# Out:
# <ipython-input-36-eed69a23ed16>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="MaritalStatus", data = aerofit, palette="BuGn")

# %%
sns.countplot(x = "Product", hue = "MaritalStatus", data = aerofit)
plt.show()

# %% [markdown]
# As we can see,
# 1. The partnered/committed people has purchased more products than people who are single,This is True for all three products.
# 2. The KP281 is The most preferred product for both Singles as Well as Couples,then followed by KP481 and KP781 respectively.
# 3. Maybe it's because KP281 is Cheaper.

# %%
sns.kdeplot(x = "Miles", data = aerofit, hue = "MaritalStatus")
plt.show()

# %% [markdown]
# 1.   Partnered people are using more treadmills for workouts
# 2.   Partnered status works out even beyond 200 miles, whereas 200 miles is the upper limit for Singles.

# %%
sns.boxplot(x="Income", data=aerofit)
plt.show()

# %%
p75, p25 = np.percentile(aerofit['Income'], [75 ,25])
iqr_income = p75 - p25
print(p25)
print(p75)
iqr_income
# Out:
# 44058.75
# 58668.0
# 14609.25

# %% [markdown]
# *   Most of the customers have income between 44k-58k
# *   Very few people have income more than 80k
# *   Difference between 25th and 75th percentile is 14609$.

# %%
#Income by gender and marital status
sns.catplot( x = "Gender" , y = "Income", col = "MaritalStatus", hue = "Product", palette = "viridis", kind = "bar", data = aerofit)
plt.show()

# %% [markdown]
# 1.   There are more single Males buying treadmill than single Females.
# 2.   Distribution of KP481 in Single & Parterned, Male & Female is same.
# 3.   Single Male customers bought KP781 treadmill compared to single Female.
# 4.   Partnered Female bought KP781 treadmill compared to Partnered Male.

# %% [markdown]
# #Marginal Probability

# %%
aerofit["Product"].value_counts(normalize = True)
# Out:
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: proportion, dtype: float64

# %% [markdown]
# **Marginal Probability - P(Product)**
#
# 1.   Probability of people buying KP281,P(Product = KP281) = 0.44
# 2.   Probability of people buying KP481,P(Product = KP481) = 0.33
# 3.   Probability of people buying KP781,P(Product = KP781) = 0.22

# %%
aerofit["Gender"].value_counts(normalize = True)
# Out:
# Gender
# Male      0.577778
# Female    0.422222
# Name: proportion, dtype: float64

# %% [markdown]
# **Marginal Probability - P(Gender)**
#
# 1.   Probability of customer being male,P(Gender = Male) = 0.58
# 2.   Probability of customer being female,P(Gender = female) = 0.42

# %%
aerofit["MaritalStatus"].value_counts(normalize = True)
# Out:
# MaritalStatus
# Partnered    0.594444
# Single       0.405556
# Name: proportion, dtype: float64

# %% [markdown]
# **Marginal Probability - P(Marital Status)**
#
# 1.   Probability of a customer's Marital Status is Partnered,P(MaritalStatus = Partnered) = 0.59
# 2.   Probability of a customer's Marital Status is single,P(MaritalStatus = Single) = 0.40

# %%
aerofit["Usage"].value_counts(normalize = True)
# Out:
# Usage
# 3    0.383333
# 4    0.288889
# 2    0.183333
# 5    0.094444
# 6    0.038889
# 7    0.011111
# Name: proportion, dtype: float64

# %% [markdown]
# **Marginal Probability - P(Usage)**
#
# 1.   Probability of a Customer using treadmill 3 Times per Week,P(Usage = 3) = 0.38
# 2.   Probability of a Customer using treadmill 4 Times per Week,P(Usage = 4) = 0.28
# 3.   Probability of a Customer using treadmill 2 Times per Week,P(Usage = 2) = 0.18
# 4.   Probability of a Customer using treadmill 5 Times per Week,P(Usage = 5) = 0.09
# 5.   Probability of a Customer using treadmill 6 Times per Week,P(Usage = 6) = 0.03
# 6.   Probability of a Customer using treadmill 7 Times per Week,P(Usage = 7) = 0.01

# %%
aerofit["Fitness"].value_counts(normalize = True)
# Out:
# Fitness
# 3    0.538889
# 5    0.172222
# 2    0.144444
# 4    0.133333
# 1    0.011111
# Name: proportion, dtype: float64

# %% [markdown]
# **Marginal Probability - P(Fitness)**
#
# 1.   Probability of a customer having a Fitness rating of 3,P(Fitness = 3) = 0.53
# 2.   Probability of a customer having a Fitness rating of 5,P(Fitness = 5) = 0.17
# 3.   Probability of a customer having a Fitness rating of 2,P(Fitness = 2) = 0.14
# 4.   Probability of a customer having a Fitness rating of 4,P(Fitness = 4) = 0.13
# 5.   Probability of a customer having a Fitness rating of 1,P(Fitness = 1) = 0.01

# %% [markdown]
# #Joint Probability

# %%
sns.heatmap(pd.crosstab(aerofit["Gender"], aerofit["Product"],margins = True, normalize = True), annot = True , cmap = "Greens")
plt.show()

# %% [markdown]
# **Joint Probability, P(Product Intersection Gender)**
#
# 1.   Probability that customer buys KP281 and gender is Male,P(KP281 Intersection Male) = 0.22
# 2.   Probability that customer buys KP481 and gender is Male,P(KP481 Intersection Male) = 0.17
# 3.   Probability that customer buys KP781 and gender is Male,P(KP781 Intersection Male) = 0.18
# 4.   Probability that customer buys KP281 and gender is female,P(KP281 Intersection female) = 0.22
# 5.   Probability that customer buys KP481 and gender is female,P(KP481 Intersection female) = 0.16
# 6.   Probability that customer buys KP781 and gender is female,P(KP781 Intersection female) = 0.039

# %%
sns.heatmap(pd.crosstab(aerofit["MaritalStatus"], aerofit["Product"],margins = True, normalize = True), annot = True , cmap = "Greens")
plt.show()

# %% [markdown]
# **Joint Probability, P(Product Intersection Marital Status)**
#
# 1.   Probability that a customer buys KP281 and Their Marital Status is Single,P(KP281 Intersection Single) = 0.18
# 2.   Probability that a customer buys KP481 and Their Marital Status is Single,P(KP481 Intersection Single) = 0.13
# 3.   Probability that a customer buys KP781 and Their Marital Status is Single,P(KP781 Intersection Single) = 0.094
# 4.   Probability that a customer buys KP281 and Their Marital Status is Partnered,P(KP281 Intersection Partnered) = 0.27
# 5.   Probability that a customer buys KP481 and Their Marital Status is Partnered,P(KP481 Intersection Partnered) = 0.2
# 6.   Probability that a customer buys KP781 and Their Marital Status is Partnered,P(KP781 Intersection Partnered) = 0.13

# %%
sns.heatmap(pd.crosstab(aerofit["Fitness"], aerofit["Product"],margins = True, normalize = True), annot = True , cmap = "Greens")
plt.show()

# %% [markdown]
# **Joint Probability, P(Product Intersection Fitness)**
#
# 1.   Probability of a customer buying KP281 and their fitness rating is 5,P(Product = KP281 Intersection Fitness = 5) = 0.011
# 2.   Probability of a customer buying KP481 and their fitness rating is 5,P(Product = KP481 Intersection Fitness = 5) = 0
# 3.   Probability of a customer buying KP781 and their fitness rating is 5,P(Product = KP781 Intersection Fitness = 5) = 0.16
# 4.   Probability of a customer buying KP281 and their fitness rating is 4,P(Product = KP281 Intersection Fitness = 4) = 0.05
# 5.   Probability of a customer buying KP481 and their fitness rating is 4,P(Product = KP481 Intersection Fitness = 4) = 0.044
# 6.   Probability of a customer buying KP781 and their fitness rating is 4,P(Product = KP781 Intersection Fitness = 4) = 0.039
# 7.   Probability of a customer buying KP281 and their fitness rating is 3,P(Product = KP281 Intersection Fitness = 3) = 0.3
# 8.   Probability of a customer buying KP481 and their fitness rating is 3,P(Product = KP481 Intersection Fitness = 3) = 0.22
# 9.   Probability of a customer buying KP781 and their fitness rating is 3,P(Product = KP781 Intersection Fitness = 3) = 0.022
# 10.  Probability of a customer buying KP281 and their fitness rating is 2,P(Product = KP281 Intersection Fitness = 2) = 0.078
# 11.  Probability of a customer buying KP481 and their fitness rating is 2,P(Product = KP481 Intersection Fitness = 2) = 0.067
# 12.  Probability of a customer buying KP781 and their fitness rating is 2,P(Product = KP781 Intersection Fitness = 2) = 0
# 13.  Probability of a customer buying KP281 and their fitness rating is 1,P(Product = KP281 Intersection Fitness = 1) = 0.0056
# 14.  Probability of a customer buying KP481 and their fitness rating is 1,P(Product = KP481 Intersection Fitness = 1) = 0.0056
# 15.  Probability of a customer buying KP781 and their fitness rating is 1,P(Product = KP781 Intersection Fitness = 1) = 0

# %% [markdown]
# #Conditional Probability

# %%
sns.heatmap(pd.crosstab(aerofit["Gender"], aerofit["Product"], normalize = "index"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(Product | Gender)**
#
# 1.   Probability of buying KP281 given that the customer is Male,P(Product = KP281 | Customer = Male) = 0.38
# 2.   Probability of buying KP481 given that the customer is Male,P(Product = KP481 | Customer = Male) = 0.3
# 3.   Probability of buying KP781 given that the customer is Male,P(Product = KP781 | Customer = Male) = 0.32
# 4.   Probability of buying KP281 given that the customer is Female,P(Product = KP281 | Customer = Female) = 0.53
# 5.   Probability of buying KP481 given that the customer is Female,P(Product = KP481 | Customer = Female) = 0.38
# 6.   Probability of buying KP781 given that the customer is Female,P(Product = KP781 | Customer = Female) = 0.092

# %%
sns.heatmap(pd.crosstab(aerofit["Gender"], aerofit["Product"], normalize = "columns"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(Gender | Product)**
#
# 1.   Probability of a customer being Male given that he bought KP281,P(Gender = Male | Product = KP281) = 0.5
# 2.   Probability of a customer being Male given that he bought KP481,P(Gender = Male | Product = KP481) = 0.52
# 3.   Probability of a customer being Male given that he bought KP781,P(Gender = Male | Product = KP781) = 0.82
# 4.   Probability of a customer being Female given that she bought KP281,P(Gender = Female | Product = KP281) = 0.5
# 5.   Probability of a customer being Female given that she bought KP481,P(Gender = Female | Product = KP481) = 0.48
# 6.   Probability of a customer being Female given that she bought KP781,P(Gender = Female | Product = KP781) = 0.17

# %%
sns.heatmap(pd.crosstab(aerofit["MaritalStatus"], aerofit["Product"], normalize = "index"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(Product | MaritalStatus)**
#
# 1.   Probability of buying KP281 given that the Marital Status is Single,P(Product = KP281 | MaritalStatus = Single) = 0.44
# 2.   Probability of buying KP481 given that the Marital Status is Single,P(Product = KP481 | MaritalStatus = Single) = 0.33
# 3.   Probability of buying KP781 given that the Marital Status is Single,P(Product = KP781 | MaritalStatus = Single) = 0.23
# 4.   Probability of buying KP281 given that the Marital Status is Partnered,P(Product = KP281 | MaritalStatus = Partnered) = 0.45
# 5.   Probability of buying KP481 given that the Marital Status is Partnered,P(Product = KP481 | MaritalStatus = Partnered) = 0.34
# 6.   Probability of buying KP781 given that the Marital Status is Partnered,P(Product = KP781 | MaritalStatus = Partnered) = 0.21

# %%
sns.heatmap(pd.crosstab(aerofit["MaritalStatus"], aerofit["Product"], normalize = "columns"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(MaritalStatus | Product)**
#
# 1.   Probability of Marital Status being Single given that KP281 is bought,P(MaritalStatus = Single | Product = KP281) = 0.4
# 2.   Probability of Marital Status being Single given that KP481 is bought,P(MaritalStatus = Single | Product = KP481) = 0.4
# 3.   Probability of Marital Status being Single given that KP781 is bought,P(MaritalStatus = Single | Product = KP781) = 0.42
# 4.   Probability of Marital Status being Partnered given that KP281 is bought,P(MaritalStatus = Partnered | Product = KP281) = 0.6
# 5.   Probability of Marital Status being Partnered given that KP481 is bought,P(MaritalStatus = Partnered | Product = KP481) = 0.6
# 6.   Probability of Marital Status being Partnered given that KP781 is bought,P(MaritalStatus = Partnered | Product = KP781) = 0.57

# %%
sns.heatmap(pd.crosstab(aerofit["Fitness"], aerofit["Product"], normalize = "index"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(Product | Fitness)**
#
# 1.   Probability of a customer buying KP281 given that the Fitness rating is 5,P(Product=KP281 | Fitness=5) = 0.065
# 2.   Probability of a customer buying KP481 given that the Fitness rating is 5,P(Product=KP481 | Fitness=5) = 0
# 3.   Probability of a customer buying KP781 given that the Fitness rating is 5,P(Product=KP781 | Fitness=5) = 0.94
# 4.   Probability of a customer buying KP281 given that the Fitness rating is 4,P(Product=KP281 | Fitness=4) = 0.38
# 5.   Probability of a customer buying KP481 given that the Fitness rating is 4,P(Product=KP481 | Fitness=4) = 0.33
# 6.   Probability of a customer buying KP781 given that the Fitness rating is 4,P(Product=KP781 | Fitness=4) = 0.29
# 7.   Probability of a customer buying KP281 given that the Fitness rating is 3,P(Product=KP281 | Fitness=3) = 0.56
# 8.   Probability of a customer buying KP481 given that the Fitness rating is 3,P(Product=KP481 | Fitness=3) = 0.4
# 9.   Probability of a customer buying KP781 given that the Fitness rating is 3,P(Product=KP781 | Fitness=3) = 0.041
# 10.  Probability of a customer buying KP281 given that the Fitness rating is 2,P(Product=KP281 | Fitness=2) = 0.54
# 11.  Probability of a customer buying KP481 given that the Fitness rating is 2,P(Product=KP481 | Fitness=2) = 0.46
# 12.  Probability of a customer buying KP781 given that the Fitness rating is 2,P(Product=KP781 | Fitness=2) = 0
# 13.  Probability of a customer buying KP281 given that the Fitness rating is 1,P(Product=KP281 | Fitness=1) = 0.5
# 14.  Probability of a customer buying KP481 given that the Fitness rating is 1,P(Product=KP481 | Fitness=1) = 0.5
# 15.  Probability of a customer buying KP781 given that the Fitness rating is 1,P(Product=KP781 | Fitness=1) = 0

# %%
sns.heatmap(pd.crosstab(aerofit["Fitness"], aerofit["Product"], normalize = "columns"), annot = True , cmap = "Blues")
plt.show()

# %% [markdown]
# **Conditional Probability, P(Fitness | Product)**
#
# 1.   Probability of a customer having Fitness rating of 5 Given that they bought KP281,P(Fitness=5 | Product = KP281) = 0.025
# 2.   Probability of a customer having Fitness rating of 5 Given that they bought KP481,P(Fitness=5 | Product = KP481) = 0
# 3.   Probability of a customer having Fitness rating of 5 Given that they bought KP781,P(Fitness=5 | Product = KP781) = 0.72
# 4.   Probability of a customer having Fitness rating of 4 Given that they bought KP281,P(Fitness=4 | Product = KP281) = 0.11
# 5.   Probability of a customer having Fitness rating of 4 Given that they bought KP481,P(Fitness=4 | Product = KP481) = 0.13
# 6.   Probability of a customer having Fitness rating of 4 Given that they bought KP781,P(Fitness=4 | Product = KP781) = 0.17
# 7.   Probability of a customer having Fitness rating of 3 Given that they bought KP281,P(Fitness=3 | Product = KP281) = 0.68
# 8.   Probability of a customer having Fitness rating of 3 Given that they bought KP481,P(Fitness=3 | Product = KP481) = 0.65
# 9.   Probability of a customer having Fitness rating of 3 Given that they bought KP781,P(Fitness=3 | Product = KP781) = 0.1
# 10.  Probability of a customer having Fitness rating of 2 Given that they bought KP281,P(Fitness=2 | Product = KP281) = 0.17
# 11.  Probability of a customer having Fitness rating of 2 Given that they bought KP481,P(Fitness=2 | Product = KP481) = 0.2
# 12.  Probability of a customer having Fitness rating of 2 Given that they bought KP781,P(Fitness=2 | Product = KP781) = 0
# 13.  Probability of a customer having Fitness rating of 1 Given that they bought KP281,P(Fitness=1 | Product = KP281) = 0.013
# 14.  Probability of a customer having Fitness rating of 1 Given that they bought KP481,P(Fitness=1 | Product = KP481) = 0.017
# 15.  Probability of a customer having Fitness rating of 1 Given that they bought KP781,P(Fitness=1 | Product = KP781) = 0

# %% [markdown]
# #Customer Profiling

# %% [markdown]
# #KP281

# %% [markdown]
# 1.   KP281 is the Most Purchased product,Contributing 44.44% of the sales.
# 2.   It is the most preferred choice of Treadmill of both Genders.
# 3.   Age of KP281 customers is roughly in the range of 22-33 years & Median Age of Customers is 26 years.
# 4.   The median/mean of fitness is 3 for KP281 model.
# 5.   Mean Income of the customers buying KP281 is 46.4k dollars.
# 6.   Mean planned usage of customers is 3.
# 7.   The single female customers bought KP281 treadmill slightly more than single male customers. The partnered male customers bought KP281 slightly more than single male customers.
# 8.   Probability of buying KP281 given that the customer is Male,P(Product = KP281 | Customer = Male) = 0.38
# 9.   Probability of buying KP281 given that the customer is Female,P(Product = KP281 | Customer = Female) = 0.53
# 10.  Probability of a customer being Male given that he bought KP281,P(Gender = Male | Product = KP281) = 0.5
# 11.  Probability of a customer being Female given that she bought KP281,P(Gender = Female | Product = KP281) = 0.5
# 12.  Probability that customer buys KP281 and gender is Male,P(KP281 & Male) = 0.22
# 13.  Probability that customer buys KP281 and gender is female,P(KP281 & female) = 0.22
# 14.  Probability of buying KP281 given that the Marital Status is Single,P(Product = KP281 | MaritalStatus = Single) = 0.44
# 15.  Probability of buying KP281 given that the Marital Status is Partnered,P(Product = KP281 | MaritalStatus = Partnered) = 0.45
# 16.  Probability of Marital Status being Single given that KP281 is bought,P(MaritalStatus = Single | Product = KP281) = 0.4
# 17.  Probability of Marital Status being Partnered given that KP281 is bought,P(MaritalStatus = Partnered | Product = KP281) = 0.6
# 18.  Probability that a customer buys KP281 and Their Marital Status is Single,P(KP281 & Single) = 0.18
# 19.  Probability that a customer buys KP281 and Their Marital Status is Partnered,P(KP281 & Partnered) = 0.27
# 20.  Probability of a customer buying KP281 given that the Fitness rating is 5,P(Product=KP281 | Fitness=5) = 0.065
# 21.  Probability of a customer buying KP281 given that the Fitness rating is 4,P(Product=KP281 | Fitness=4) = 0.38
# 22.  Probability of a customer buying KP281 given that the Fitness rating is 3,P(Product=KP281 | Fitness=3) = 0.56
# 23.  Probability of a customer buying KP281 given that the Fitness rating is 2,P(Product=KP281 | Fitness=2) = 0.54
# 24.  Probability of a customer buying KP281 given that the Fitness rating is 1,P(Product=KP281 | Fitness=1) = 0.5
# 25.  Probability of a customer having Fitness rating of 5 Given that they bought KP281,P(Fitness=5 | Product = KP281) = 0.025
# 26.  Probability of a customer having Fitness rating of 4 Given that they bought KP281,P(Fitness=4 | Product = KP281) = 0.11
# 27.  Probability of a customer having Fitness rating of 3 Given that they bought KP281,P(Fitness=3 | Product = KP281) = 0.68
# 28.  Probability of a customer having Fitness rating of 2 Given that they bought KP281,P(Fitness=2 | Product = KP281) = 0.17
# 29.  Probability of a customer having Fitness rating of 1 Given that they bought KP281,P(Fitness=1 | Product = KP281) = 0.013
# 30.  Probability of a customer buying KP281 and their fitness rating is 5,P(Product = KP281 & Fitness = 5) = 0.011
# 31.  Probability of a customer buying KP281 and their fitness rating is 4,P(Product = KP281 & Fitness = 4) = 0.05
# 32.  Probability of a customer buying KP281 and their fitness rating is 3,P(Product = KP281 I& Fitness = 3) = 0.3
# 33.  Probability of a customer buying KP281 and their fitness rating is 2,P(Product = KP281 I& Fitness = 2) = 0.078
# 34.  Probability of a customer buying KP281 and their fitness rating is 1,P(Product = KP281 & Fitness = 1) = 0.0056

# %% [markdown]
# #KP481

# %% [markdown]
# 1.   KP481 is the Second most product sold, contributing to 33.33% Sales.
# 2.   There are Slightly More Male buyers of KP481 product.
# 3.   Age of KP481 customers is roughly in the range of 23-34 years & Median Age of Customers is 26 years.
# 4.   The Mean of Fitness is 3 for KP481 model.
# 5.   Mean Income of the customers buying KP481 is 46.4k dollars.
# 6.   Mean planned usage of customers is 3.
# 7.   The single female customers bought KP481 treadmill slightly more than single male customers & It is same for Partnered male & female Customers.
# 8.   Probability of buying KP481 given that the customer is Male,P(Product = KP481 | Customer = Male) = 0.3
# 9.   Probability of buying KP481 given that the customer is Female,P(Product = KP481 | Customer = Female) = 0.38
# 10.  Probability of a customer being Male given that he bought KP481,P(Gender = Male | Product = KP481) = 0.52
# 11.  Probability of a customer being Female given that she bought KP481,P(Gender = Female | Product = KP481) = 0.48
# 12.  Probability that customer buys KP481 and gender is Male,P(KP481 & Male) = 0.17
# 13.  Probability that customer buys KP481 and gender is female,P(KP481 & female) = 0.16
# 14.  Probability of buying KP481 given that the Marital Status is Single,P(Product = KP481 | MaritalStatus = Single) = 0.33
# 15.  Probability of buying KP481 given that the Marital Status is Partnered,P(Product = KP481 | MaritalStatus = Partnered) = 0.34
# 16.  Probability of Marital Status being Single given that KP481 is bought,P(MaritalStatus = Single | Product = KP481) = 0.4
# 17.  Probability of Marital Status being Partnered given that KP481 is bought,P(MaritalStatus = Partnered | Product = KP481) = 0.6
# 18.  Probability that a customer buys KP481 and Their Marital Status is Single,P(KP481 & Single) = 0.13
# 19.  Probability that a customer buys KP481 and Their Marital Status is Partnered,P(KP481 & Partnered) = 0.2
# 20.  Probability of a customer buying KP481 given that the Fitness rating is 5,P(Product=KP481 | Fitness=5) = 0
# 21.  Probability of a customer buying KP481 given that the Fitness rating is 4,P(Product=KP481 | Fitness=4) = 0.33
# 22.  Probability of a customer buying KP481 given that the Fitness rating is 3,P(Product=KP481 | Fitness=3) = 0.4
# 23.  Probability of a customer buying KP481 given that the Fitness rating is 2,P(Product=KP481 | Fitness=2) = 0.46
# 24.  Probability of a customer buying KP481 given that the Fitness rating is 1,P(Product=KP481 | Fitness=1) = 0.5
# 25.  Probability of a customer having Fitness rating of 5 Given that they bought KP481,P(Fitness=5 | Product = KP481) = 0
# 26.  Probability of a customer having Fitness rating of 4 Given that they bought KP481,P(Fitness=4 | Product = KP481) = 0.13
# 27.  Probability of a customer having Fitness rating of 3 Given that they bought KP481,P(Fitness=3 | Product = KP481) = 0.65
# 28.  Probability of a customer having Fitness rating of 2 Given that they bought KP481,P(Fitness=2 | Product = KP481) = 0.2
# 29.  Probability of a customer having Fitness rating of 1 Given that they bought KP481,P(Fitness=1 | Product = KP481) = 0.017
# 30.  Probability of a customer buying KP481 and their fitness rating is 5,P(Product = KP481 & Fitness = 5) = 0
# 31.  Probability of a customer buying KP481 and their fitness rating is 4,P(Product = KP481 & Fitness = 4) = 0.044
# 32.  Probability of a customer buying KP481 and their fitness rating is 3,P(Product = KP481 & Fitness = 3) = 0.22
# 33.  Probability of a customer buying KP481 and their fitness rating is 2,P(Product = KP481 & Fitness = 2) = 0.067
# 34.  Probability of a customer buying KP481 and their fitness rating is 1,P(Product = KP481 & Fitness = 1) = 0.0056

# %% [markdown]
# #KP781

# %% [markdown]
# 1.   KP781 is the Least bought treadmill,contributing to 22.22% of sales.
# 2.   KP781 is the most preferred among males, while very few females buy KP781.
# 3.   Age of KP781 customers is roughly in the range of 24-31 years & Median age of Customers is 27 years.
# 4.   The mean fitness rating of KP781 buyers is 4.
# 5.   Mean Income of the customers buying KP781 is 75.4k dollars.Few people have bought KP781. because,Maybe their income is high.
# 6.   The mean planned usage of KP781 customers is 4.
# 7.   Single Male customers bought KP781 treadmills compared to single Females.Whereas, Partnered Female bought KP781 treadmill compared to Partnered Male.
# 8.   Probability of buying KP781 given that the customer is Male,P(Product = KP781 | Customer = Male) = 0.32
# 9.   Probability of buying KP781 given that the customer is Female,P(Product = KP781 | Customer = Female) = 0.092
# 10.  Probability of a customer being Male given that he bought KP781,P(Gender = Male | Product = KP781) = 0.82
# 11.  Probability of a customer being Female given that she bought KP781,P(Gender = Female | Product = KP781) = 0.17
# 12.  Probability that customer buys KP781 and gender is Male,P(KP781 & Male) = 0.18
# 13.  Probability that customer buys KP781 and gender is female,P(KP781 & female) = 0.039
# 14.  Probability of buying KP781 given that the Marital Status is Single,P(Product = KP781 | MaritalStatus = Single) = 0.23
# 15.  Probability of buying KP781 given that the Marital Status is Partnered,P(Product = KP781 | MaritalStatus = Partnered) = 0.21
# 16.  Probability of Marital Status being Single given that KP781 is bought,P(MaritalStatus = Single | Product = KP781) = 0.42
# 17.  Probability of Marital Status being Partnered given that KP781 is bought,P(MaritalStatus = Partnered | Product = KP781) = 0.57
# 18.  Probability that a customer buys KP781 and Their Marital Status is Single,P(KP781 & Single) = 0.094
# 19.  Probability that a customer buys KP781 and Their Marital Status is Partnered,P(KP781 & Partnered) = 0.13
# 20.  Probability of a customer buying KP781 given that the Fitness rating is 5,P(Product=KP781 | Fitness=5) = 0.94
# 21.  Probability of a customer buying KP781 given that the Fitness rating is 4,P(Product=KP781 | Fitness=4) = 0.29
# 22.  Probability of a customer buying KP781 given that the Fitness rating is 3,P(Product=KP781 | Fitness=3) = 0.041
# 23.  Probability of a customer buying KP781 given that the Fitness rating is 2,P(Product=KP781 | Fitness=2) = 0
# 24.  Probability of a customer buying KP781 given that the Fitness rating is 1,P(Product=KP781 | Fitness=1) = 0
# 25.  Probability of a customer having Fitness rating of 5 Given that they bought KP781,P(Fitness=5 | Product = KP781) = 0.72
# 26.  Probability of a customer having Fitness rating of 4 Given that they bought KP781,P(Fitness=4 | Product = KP781) = 0.17
# 27.  Probability of a customer having Fitness rating of 3 Given that they bought KP781,P(Fitness=3 | Product = KP781) = 0.1
# 28.  Probability of a customer having Fitness rating of 2 Given that they bought KP781,P(Fitness=2 | Product = KP781) = 0
# 29.  Probability of a customer having Fitness rating of 1 Given that they bought KP781,P(Fitness=1 | Product = KP781) = 0
# 30.  Probability of a customer buying KP781 and their fitness rating is 5,P(Product = KP781 Intersection Fitness = 5) = 0.16
# 31.  Probability of a customer buying KP781 and their fitness rating is 4,P(Product = KP781 Intersection Fitness = 4) = 0.039
# 32.  Probability of a customer buying KP781 and their fitness rating is 3,P(Product = KP781 Intersection Fitness = 3) = 0.022
# 33.  Probability of a customer buying KP781 and their fitness rating is 2,P(Product = KP781 Intersection Fitness = 2) = 0
# 34.  Probability of a customer buying KP781 and their fitness rating is 1,P(Product = KP781 Intersection Fitness = 1) = 0

# %% [markdown]
# #Recommendations

# %% [markdown]
# 1.   As KP781 provides more features and functionalities & It's Fitness rating is 4 meaning it is used by fitter people,Hence, the treadmill should be marketed for professionals and athletes.
# 2.   The KP781 should be Advertised by fittest & most popular athelites for More Sale.For Example - Virat Kohli.
# 3.   A Marketing Campaign should be carried out on social Platforms to Promote importance of exercise to Women.
# 4.   As the Sales by Couples is more than Single people,Special Discounts should be given to Couples/Partnered people in order to Maximize the Sales.
# 5.   KP281 & KP481 treadmills are preferred by the customers whose annual income lies in the range of 40K - 55K Dollars. These models should promote as The Affordable Treadmills.
